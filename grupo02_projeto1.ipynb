# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianoMata/projeto_final_mod04/blob/main/grupo02_projeto1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Tudo.csv', parse_dates=['Data da Coleta'], sep=';')
df
# Out:
#       Região - Sigla  ...                      Bandeira
# 0                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 1                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 2                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 3                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 4                  N  ...                        BRANCA
# ...              ...  ...                           ...
# 97581             SE  ...                        BRANCA
# 97582             SE  ...                        BRANCA
# 97583             SE  ...                        BRANCA
# 97584             SE  ...                    RIO BRANCO
# 97585             SE  ...                    RIO BRANCO
#
# [97586 rows x 15 columns]
